# %% [markdown]
# #Import

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# #Data preparation

# %%
assets = 'assets.csv'

assets = pd.read_csv(assets)

y = assets.Price

assets_features = ['Market Cap (in M)', 'Beta', 'Volume 52 weeks', 'Performance (52 weeks)', 'Résultat net', 'Price 52 Weeks Ago', 'Total assets']

X = assets[assets_features]

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 1)

# %% [markdown]
# #Linear Regression

# %%
assets_model = LinearRegression()

assets_model.fit(train_X, train_y)

val_predictions = assets_model.predict(val_X)

print('Val prediction :', val_predictions)

print('MAE :', mean_absolute_error(val_y, val_predictions))
# Out:
# Val prediction : [ 26.35666286  75.68784044  20.45913131 ...  32.00144633  50.07943741
#  126.01166263]
# MAE : 33.12172340482808

# %% [markdown]
# #Decision Tree

# %%
assets_model = DecisionTreeRegressor()

assets_model.fit(train_X, train_y)

val_predictions = assets_model.predict(val_X)

print('Val prediction :', val_predictions)

print('MAE :',mean_absolute_error(val_y, val_predictions))
# Out:
# Val prediction : [  9.96 105.66   1.41 ...  22.35  67.65 276.61]
# MAE : 5.269954861730597

# %% [markdown]
# #Random Forest Regression

# %%
assets_model = RandomForestRegressor()

assets_model.fit(train_X, train_y)

val_predictions = assets_model.predict(val_X)

print('Val prediction :', val_predictions)

print('MAE :',mean_absolute_error(val_y, val_predictions))
# Out:
# Val prediction : [  9.49015  106.2609     1.143211 ...  21.3969    65.1919   238.2763  ]
# MAE : 3.5276989458340773
